# %%
import requests
from bs4 import BeautifulSoup
import json
import concurrent.futures
import os
import pandas as pd

# Đọc file CSV
list_file = "all_link_for_craw_1802.csv"
df = pd.read_csv(list_file, encoding='utf-8')
print(f"Cases for craw: {len(df)}")
# print(df.head(5))

def detailinforequest(index, cntyCd, baseYy, reffNoNm, prlstClsfSrno):

    url = 'https://unipass.customs.go.kr/clip/prlstclsfsrch/retrievePrlstClsfCaseDtl.do'

    headers = {
        'Accept': 'text/html, */*; q=0.01',
        'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8,vi-VN;q=0.7',
        'Connection': 'keep-alive',
        'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'Cookie': 'WMONID=N_4A3dINH0I; JSESSIONID=0001O2y8S-yyQQ_lga-knblPV6Lb2QN6662ivRFJ_jK2FPRlLOTKNEsnuhZe_QxBEKq-8U03_kah8EgUgb-_Exa4dmevvhJHEKeNuIq9prRxpJht6ugFASENgz3p_AdMPw4_:eul21',
        'DNT': '1',
        'Origin': 'https://unipass.customs.go.kr',
        'Referer': 'https://unipass.customs.go.kr/clip/index.do',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-origin',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36',
        'X-Requested-With': 'XMLHttpRequest',
        'isAjax': 'true',
        'sec-ch-ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"'
    }

    #body 
    payload = {
        'cntyCd': cntyCd,
        'baseYy': baseYy,
        'reffNoNm': reffNoNm,
        'prlstClsfSrno': prlstClsfSrno
    }

    # POST với headers và body
    response = requests.post(url, headers=headers, data=payload,timeout=60)

    if response.status_code == 200:
        return response.text, index
    else:
        print(f"Row {index} Lỗi")
        return None, index


def extract_data_from_html(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    result = {}
    for table_type in ('org','eng','kor'):
        table = soup.find("table", class_=table_type)
        # Tìm thẻ <p> chứa từ khóa "상세결과 항목 :"
        all_ths = table.findAll('th')
        for th in all_ths: 
            if th.get_text() == "관련 이미지":
                image_elements = table.find('th', text='관련 이미지').find_next_sibling('td').find_all('img')
                image_links = [img['src'] for img in image_elements]
                result[f"{th.get_text()}_{table_type}"] = image_links
            # print(f"Đang xử lý: {catalog}")
            else: 
                elems_html_info = table.find('th', text=th.get_text()).find_next_sibling('td')
                for elem in elems_html_info:
                    if elem.name == 'a':  # Thay đổi thẻ <a> thành văn bản
                        elem.replace_with(elem.text)
                    elif elem.name == 'br':  # Giữ lại thẻ <br>
                        continue
                elem_text = elems_html_info.decode_contents().replace('\r', '').replace('\t', '').replace('\n', '').strip()
                result[f"{th.get_text()}_{table_type}"] = elem_text
    print(result)
    return result


def save_state(states, thread_index):
    with open(state_file_template.format(thread_index), "w") as f:
        json.dump(states, f)


def load_state(thread_index):
    try:
        with open(state_file_template.format(thread_index), "r") as f:
            states = json.load(f)
            if isinstance(states, dict) and "start_index" in states:
                return states
            else:
                return {"start_index": 0}
    except FileNotFoundError:
        return {"start_index": 0}


def process_data_chunk(data_chunk, thread_index, start_index):

    all_detail_output = []
    error_stt_list = []
    current_index = start_index
    
    while True:
        try:
            for index, row in data_chunk.iloc[start_index:].iterrows():
                cntyCd = row['cntyCd']
                baseYy = row['baseYy']
                reffNoNm = row['reffNoNm']
                prlstClsfSrno = row['prlstClsfSrno']
                stt = row['stt']

                try:
                    html_content, index = detailinforequest(index, cntyCd, baseYy, reffNoNm, prlstClsfSrno)
                    if html_content:
                        detail_output = extract_data_from_html(html_content)
                        detail_output["stt"] = stt
                        all_detail_output.append(detail_output)

                        # Ghi kết quả vào file riêng cho thread
                        with open(output_file_template.format(thread_index), "a", encoding='utf-8') as f:
                            f.write(json.dumps(detail_output, ensure_ascii=False) + "\n")

                except Exception as e:
                    print(f"Error processing row {index}: {e}")
                    error_stt_list.append(stt)
                    
                    # Ghi lỗi vào file
                    with open(error_file_template.format(thread_index), "a", encoding='utf-8') as f:
                        f.write(json.dumps({"stt": stt, "error": str(e)}, ensure_ascii=False) + "\n")
                    
                finally:
                    # Cập nhật trạng thái đã xử lý
                    current_index = index + 1  
                    save_state({"start_index": current_index}, thread_index)

            return all_detail_output, current_index, error_stt_list
        except Exception as e:
            print(f"Thread {thread_index} encountered an error: {e}. Restarting...")
            time.sleep(5)  # Đợi 5 giây trước khi thử lại

# Thư mục để lưu trạng thái và kết quả
output_dir = "org"
os.makedirs(output_dir, exist_ok=True)

# File để lưu trạng thái của vòng lặp
state_file_template = os.path.join(output_dir, "loop_state_{}.json")
output_file_template = os.path.join(output_dir, "output_data_{}.txt")
error_file_template = os.path.join(output_dir, "error_stt_{}.txt")
final_output_file = "final_output_data_org.txt"  # File tổng kết quả

# Bắt đầu vòng lặp từ trạng thái đã lưu
chunk_size = 1000
df_chunks = [chunk.reset_index(drop=True) for chunk in [df[i:i + chunk_size] for i in range(0, len(df), chunk_size)]]

# Bắt đầu vòng lặp từ trạng thái đã lưu
saved_states = [load_state(i) for i in range(len(df_chunks))]

# Sử dụng multithreading để xử lý từng chunk
# all_results = []
# all_error_stts = []
states = {}

with concurrent.futures.ThreadPoolExecutor(max_workers=len(df_chunks)) as executor:
    futures = {
        executor.submit(process_data_chunk, chunk, idx, saved_states[idx]["start_index"]): idx
        for idx, chunk in enumerate(df_chunks)
    }
    for future in concurrent.futures.as_completed(futures):
        thread_index = futures[future]
        try:
            results, current_index, error_stts = future.result()
            # all_results.extend(results)
            # all_error_stts.extend(error_stts)
            states[thread_index] = {"start_index": current_index}
        except Exception as e:
            print(f"Thread {thread_index} encountered an error: {e}")
            save_state(states[thread_index], thread_index)

# # Ghi tất cả các lỗi vào file chung
# with open("final_error_stts.txt", "w", encoding='utf-8') as f:
#     for error_stt in all_error_stts:
#         f.write(f"{error_stt}\n")

# # Lưu kết quả cuối cùng
# with open(final_output_file, "w", encoding='utf-8') as f:
#     for result in all_results:
#         f.write(json.dumps(result, ensure_ascii=False) + "\n")
# Out:
# Cases for craw: 10161
# C:\Users\nguye\AppData\Local\Temp\ipykernel_17840\3807799809.py:70: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   elems_html_info = table.find('th', text=th.get_text()).find_next_sibling('td')
# C:\Users\nguye\AppData\Local\Temp\ipykernel_17840\3807799809.py:65: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   image_elements = table.find('th', text='관련 이미지').find_next_sibling('td').find_all('img')
# {'기준년도_org': '2024', '참조번호_org': 'XIBTI505064872', '시행일자_org': '2024-09-12', '결정세번_org': '8503009999************', '물품설명_org': 'A stator, it is a series of wire coils that are formed into a tubular shape around the inside of the motor housing. The rotor assembly of the motor is positioned inside the coils and rotates when an electrical current is applied to the stator<br/>The stator forms part of a motor and generates a magnetic field to facilitate rotation of the rotor assembly<br/>The stator is made from a combination of steel, aluminium and copper materials. Stator is manufactured to a confidential drawing specification<br/>The electric motors have a power range of between 2-7HP and there are 3 types of motors ? single phase, 3 phase and variable speed.', '분류사유_org': 'Classification has been determined in accordance with the following:-<br/>General Interpretative Rules (GIR)s:<br/><br/>GIR 1 has been used to classify this product by the terms of heading 8503 - Parts suitable for use solely or principally with the machines of heading 8501 or 8502 <br/><br/>CN Code 8503 0099 ? Other than non-magnetic retaining rings; other than of cast iron or steel<br/><br/>TARIC Code 8503 0099 99 - Other than elsewhere specified<br/>Harmonised Standard Explanatory Notes (HSENs) to heading 8503', '이슈장소_org': '', '키워드_org': 'STATORS<br/>PART OF<br/>ELECTRICALLY OPERATED<br/>COILS<br/>OF COPPER', '관련 이미지_org': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241120-000059690081nZ4o', '/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241120-000059690092nZN3'], '기준년도_eng': '2024', '참조번호_eng': 'XIBTI505064872', '시행일자_eng': '2024-09-12', '결정세번_eng': '8503009999************', '물품설명_eng': 'A stator, it is a series of wire coils that are formed into a tubular shape around the inside of the motor housing. The rotor assembly of the motor is positioned inside the coils and rotates when an electrical current is applied to the stator<br/>The stator forms part of a motor and generates a magnetic field to facilitate rotation of the rotor assembly<br/>The stator is made from a combination of steel, aluminium and copper materials. Stator is manufactured to a confidential drawing specification<br/>The electric motors have a power range of between 2-7HP and there are 3 types of motors ? single phase, 3 phase and variable speed.', '분류사유_eng': 'Classification has been determined in accordance with the following:-<br/>General Interpretative Rules (GIR)s:<br/><br/>GIR 1 has been used to classify this product by the terms of heading 8503 - Parts suitable for use solely or principally with the machines of heading 8501 or 8502 <br/><br/>CN Code 8503 0099 ? Other than non-magnetic retaining rings; other than of cast iron or steel<br/><br/>TARIC Code 8503 0099 99 - Other than elsewhere specified<br/>Harmonised Standard Explanatory Notes (HSENs) to heading 8503', '이슈장소_eng': '', '키워드_eng': 'STATORS<br/>PART OF<br/>ELECTRICALLY OPERATED<br/>COILS<br/>OF COPPER', '관련 이미지_eng': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241120-000059690081nZ4o', '/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241120-000059690092nZN3'], '기준년도_kor': '2024', '참조번호_kor': 'XIBTI505064872', '시행일자_kor': '2024-09-12', '결정세번_kor': '8503009999************', '물품설명_kor': '스테이터는 모터 하우징 내부를 따라 관 모양으로 형성된 일련의 와이어 코일입니다. 모터의 로터 어셈블리는 코일 내부에 위치하고 스테이터에 전류가 인가되면 회전합니다. 스테이터는 모터의 일부를 형성하고 로터 어셈블리의 회전을 용이하게 하기 위해 자기장을 생성합니다. 스테이터는 강철, 알루미늄 및 구리 소재의 조합으로 만들어집니다. 스테이터는 기밀 도면 사양에 따라 제조됩니다. 전기 모터의 전력 범위는 2-7HP이며 단상, 3상 및 가변 속도의 3가지 유형의 모터가 있습니다.', '분류사유_kor': '분류는 다음에 따라 결정되었습니다.- 일반 해석 규칙(GIR): GIR 1은 8503 항목의 용어에 따라 이 제품을 분류하는 데 사용되었습니다.- 8501 항목 또는 8502 항목의 기계에 단독 또는 주로 사용하기에 적합한 부품 CN 코드 8503 0099 - 비자성 고정 링 제외; 주철 또는 강철 제외 TARIC 코드 8503 0099 99 - 기타 항목 8503 항목에 대한 조화 표준 해설 주석(HSEN)', '이슈장소_kor': '', '키워드_kor': '고정자<br/>부분품의<br/>전기 작동식의 것<br/>코일<br/>구리염화물', '관련 이미지_kor': ['/clip/framework/filedownload/kcs4gImageDownload ...
# {'기준년도_org': '2024', '참조번호_org': 'IEBTIIENEN004-2024-BTI85', '시행일자_org': '2024-03-06', '결정세번_org': '2106909285************', '물품설명_org': 'Vitamin B Complex Supreme Capsules (30)<br/>A food supplement, the applicant states together with associated nutrients, it plays a key role in the body’s vital metabolism.  It helps maintain the health of the nervous system, digestive system and skin condition.<br/>The 30 capsules are presented in a glass jar with a plastic screw cap', '분류사유_org': 'G.I.R 1 &amp; 6<br/>NOTES TO CHAPTER 21<br/>NOTES TO CHAPTER 21 AND HEADING 2106<br/>Additional Note 5 to Chapter 21<br/>TERXT TO CODE 2106, 210690, 21069092, 2106909285<br/>LAB ADVICE R24A0016', '이슈장소_org': 'NENAGH CO TIPPERARY', '키워드_org': 'CAPSULES <br/>SCREW CAPS <br/>FOOD SUPPLEMENTS <br/>VITAMINS <br/>NERVOUS SYSTEM <br/>DIGESTIVE SYSTEM', '관련 이미지_org': [], '기준년도_eng': '2024', '참조번호_eng': 'IEBTIIENEN004-2024-BTI85', '시행일자_eng': '2024-03-06', '결정세번_eng': '2106909285************', '물품설명_eng': 'Vitamin B Complex Supreme Capsules (30)<br/>A food supplement, the applicant states together with associated nutrients, it plays a key role in the body’s vital metabolism.  It helps maintain the health of the nervous system, digestive system and skin condition.<br/>The 30 capsules are presented in a glass jar with a plastic screw cap', '분류사유_eng': 'G.I.R 1 &amp; 6<br/>NOTES TO CHAPTER 21<br/>NOTES TO CHAPTER 21 AND HEADING 2106<br/>Additional Note 5 to Chapter 21<br/>TERXT TO CODE 2106, 210690, 21069092, 2106909285<br/>LAB ADVICE R24A0016', '이슈장소_eng': 'NENAGH CO TIPPERARY', '키워드_eng': 'CAPSULES <br/>SCREW CAPS <br/>FOOD SUPPLEMENTS <br/>VITAMINS <br/>NERVOUS SYSTEM <br/>DIGESTIVE SYSTEM', '관련 이미지_eng': [], '기준년도_kor': '2024', '참조번호_kor': 'IEBTIIENEN004-2024-BTI85', '시행일자_kor': '2024-03-06', '결정세번_kor': '2106909285************', '물품설명_kor': '비타민 B 복합제 슈프림 캡슐(30) 식품 보충제로, 신청자는 관련 영양소와 함께 신체의 중요한 신진대사에 중요한 역할을 한다고 말합니다. 신경계, 소화계, 피부 상태의 건강을 유지하는 데 도움이 됩니다. 30개의 캡슐은 플라스틱 나사 캡이 달린 유리 병에 담겨 제공됩니다.', '분류사유_kor': 'GIR 1 및 6 제21장에 대한 주석 제21장과 제목 2106에 대한 주석 제21장에 대한 추가 주석 5 코드 2106, 210690, 21069092, 2106909285의 종결 실험실 조언 R24A0016', '이슈장소_kor': 'NENAGH CO TIPPERARY', '키워드_kor': '캡슐  <br/>스크류 캡  <br/>FOOD보충제  <br/>비타민  <br/>신경계  <br/>침지 시스템', '관련 이미지_kor': []}
# {'기준년도_org': '2024', '참조번호_org': 'XIBTI39269097', '시행일자_org': '2024-09-05', '결정세번_org': '84139100**************', '물품설명_org': 'The product is a bespoke gasket for use on pumps/compressors to prevent leakage of fluids or gases.<br/><br/>The gasket size depends on the mechanical seal it is being used on, this can range from ¼" to 6"s in size. They follow a circular shape to bit on a mechanical seal face, but usually will be grooved with holes cut in it, to allow for fitting. The mechanical seal gasket material is generally green in colour<br/>The gasket sheets are usually stacked flat and packed in protective wrapping to prevent damage during transportation. <br/>Other: Some will be supplied with adhesive backing to allow them to be stuck in place of the seal face.<br/>These mechanical seal gaskets serve to create a seal between two surfaces, preventing the leakage of fluids or gases under various conditions, such as pressure and temperature.<br/>Product is made of aramid fibres, NBR Binder, <br/><br/>The manufacturing process typically involves mixing the raw materials, including aramid fibres, inorganic fillers, and the NBR binder to form a homogenous blend.<br/>The mixture is then calendared into sheets of the desired thickness. This involves passing the material through rollers to achieve uniform thickness and density.<br/>The sheets are then subjected to a heat treatment process called curing, where the rubber binder is vulcanized, enhancing the material\'s properties such as elasticity and chemical resistance.<br/>Finally, the cured sheets are cut to the required dimensions and shapes as per specific bespoke gasket designs.<br/>These mechanical seal gaskets are bespoke designed for use only with one of our mechanical seals. All sizing and dimensions will limit them only to be used within one of our seals. The gaskets are ordered to an internally produced technical drawing.', '분류사유_org': 'Classification has been determined in accordance with the following:-<br/>General Interpretative Rules (GIR)s:<br/>GIR 1 has been used to classify this product by the terms of heading 3926 - Other articles of plastics and articles of other materials of headings 3901 to 3914<br/>GIR 5 (b) has been used to identify normal packaging for transport <br/>GIR 6 has been used to classify the goods to sub-heading 3926.90 ? Other than elsewhere specified in this heading<br/>CN Code 3926 9097 ? Other than elsewhere specified in this subheading<br/>Harmonised Standard Explanatory Notes (HSENs) to heading 3926<br/>Considered classification to heading 8413 which covers pumps for liquids and parts therefor. Excluded from this heading as the goods are intended for other applications such as compressors and not restricted to being used just for parts of pumps, therefore classified as parts of general use', '이슈장소_org': '', '키워드_org': 'GASKETS<br/>PART OF<br/>OF PLASTICS<br/>POLYAMIDES<br/>INDUSTRIAL MACHINERY', '관련 이미지_org': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241120-000059690070uLqv'], '기준년도_eng': '2024', '참조번호_eng': 'XIBTI39269097', '시행일자_eng': '2024-09-05', '결정세번_eng': '84139100**************', '물품설명_eng': 'The product is a bespoke gasket for use on pumps/compressors to prevent leakage of fluids or gases.<br/><br/>The gasket size depends on the mechanical seal it is being used on, this can range from ¼" to 6"s in size. They follow a circular shape to bit on a mechanical seal face, but usually will be grooved with holes cut in it, to allow for fitting. The mechanical seal gasket material is generally green in colour<br/>The gasket sheets are usually stacked flat and packed in protective wrapping to prevent damage during transportation. <br/>Other: Some will be supplied with adhesive backing to allow them to be stuck in place of the seal face.<br/>These mechanical seal gaskets serve to create a seal between two surfaces, preventing the leakage of fluids or gases under various conditions, such as pressure and temperature.< ...
# {'기준년도_org': '2024', '참조번호_org': 'XIBTI505063973', '시행일자_org': '2024-09-05', '결정세번_org': '84842000**************', '물품설명_org': 'Mechanical seal faces used in various industrial applications to prevent leakage between rotating and stationary parts. These seal faces are crafted from Tungsten Carbide due to properties allowing for thermal conductivity, resistance to wear and corrosion.<br/>They are ring shaped, of a graphite colour packaged sufficiently to protect them from damage when shipping. Sizes can be from 35mm to 200mm<br/>They are used specifically in a mechanical seal to prevent leakage. Due to the bespoke design, they can only ever be used in a mechanical seal.<br/>Tungsten Carbide. Tungsten carbide is formed by mixing tungsten and carbon powders, this is then carbonised in a furnace, the tungsten carbon powder is the compacted in desired face shape in accordance with our drawings which is then sintered.<br/>They are specifically designed and selected for the application. The rings are very light in weight due to their low density. It also important to note, due to their design, they do not have another use except within a mechanical seal.', '분류사유_org': 'Classification has been determined in accordance with the following:-<br/>General Interpretative Rules (GIR)s:<br/><br/>GIR 1 has been used to classify this product by the terms of heading 8484 - Gaskets and similar joints of metal sheeting combined with other material or of two or more layers of metal; sets or assortments of gaskets and similar joints, dissimilar in composition, put up in pouches, envelopes or similar packings; mechanical seals<br/>GIR 6 has been used to classify the goods to sub-heading 8484.20 ? Mechanical seals<br/>Harmonised Standard Explanatory Notes (HSENs) to heading 8484 ? Part C refers<br/>Considered classification to heading 8413 which covers pumps for liquids and parts therefor. Excluded from this heading as the goods are intended for various industrial applications and not specifically used as parts of pumps, therefore classified as parts of general use', '이슈장소_org': '', '키워드_org': 'TUNGSTEN<br/>RINGS, FORMS<br/>SEALS<br/>OF METAL<br/>PRECISION EQUIPMENT', '관련 이미지_org': [], '기준년도_eng': '2024', '참조번호_eng': 'XIBTI505063973', '시행일자_eng': '2024-09-05', '결정세번_eng': '84842000**************', '물품설명_eng': 'Mechanical seal faces used in various industrial applications to prevent leakage between rotating and stationary parts. These seal faces are crafted from Tungsten Carbide due to properties allowing for thermal conductivity, resistance to wear and corrosion.<br/>They are ring shaped, of a graphite colour packaged sufficiently to protect them from damage when shipping. Sizes can be from 35mm to 200mm<br/>They are used specifically in a mechanical seal to prevent leakage. Due to the bespoke design, they can only ever be used in a mechanical seal.<br/>Tungsten Carbide. Tungsten carbide is formed by mixing tungsten and carbon powders, this is then carbonised in a furnace, the tungsten carbon powder is the compacted in desired face shape in accordance with our drawings which is then sintered.<br/>They are specifically designed and selected for the application. The rings are very light in weight due to their low density. It also important to note, due to their design, they do not have another use except within a mechanical seal.', '분류사유_eng': 'Classification has been determined in accordance with the following:-<br/>General Interpretative Rules (GIR)s:<br/><br/>GIR 1 has been used to classify this product by the terms of heading 8484 - Gaskets and similar joints of metal sheeting combined with other material or of two or more layers of metal; sets or assortments of gaskets and similar joints, dissimilar in composition, put up in pouches, envelopes or similar packings; mechanical seals<br/>GIR 6 has been used to classify the goods to sub-heading 8484.20 ? Mechanical seals<br/>Harmonised Standard Explanatory Notes (HSENs) to heading 8484 ? Part C refers< ...
# {'기준년도_org': '2024', '참조번호_org': 'IEBTIIENEN004-2024-BTI72', '시행일자_org': '2024-03-06', '결정세번_org': '2106909285************', '물품설명_org': 'Chewable Capsules rich in Omega 3 fish oils.<br/>These capsules help improve brain function and concentration and help maintain general health and wellbeing.<br/>Each capsule contains omega-3 essential fatty acids EHA and DHA.  They also contain Vitamins A, D and E.<br/>These are available in orange flavour and are put up for retail sale.  There are 60 in a container.', '분류사유_org': 'G.I.R 1 &amp; 6<br/>Notes to Chapter 21<br/>ADDITIONAL NOTE (CN) 5 TO CHAPTER 21<br/>HSEN to Chapter 21 and Heading 2106<br/>Text to codes 2106, 2106 90, 2106 90 92, 85<br/> Lab Advice R24A0011<br/> Renewal of IENEN004-2023-BTI266', '이슈장소_org': 'Nenagh, Co. Tipperary, Ireland', '키워드_org': 'PUT UP FOR RETAIL SALE <br/>VITAMINS <br/>CAPSULES <br/>FOR GENERAL USE <br/>BRAIN <br/>FATTY ACIDS <br/>FOR CHILDREN', '관련 이미지_org': [], '기준년도_eng': '2024', '참조번호_eng': 'IEBTIIENEN004-2024-BTI72', '시행일자_eng': '2024-03-06', '결정세번_eng': '2106909285************', '물품설명_eng': 'Chewable Capsules rich in Omega 3 fish oils.<br/>These capsules help improve brain function and concentration and help maintain general health and wellbeing.<br/>Each capsule contains omega-3 essential fatty acids EHA and DHA.  They also contain Vitamins A, D and E.<br/>These are available in orange flavour and are put up for retail sale.  There are 60 in a container.', '분류사유_eng': 'G.I.R 1 &amp; 6<br/>Notes to Chapter 21<br/>ADDITIONAL NOTE (CN) 5 TO CHAPTER 21<br/>HSEN to Chapter 21 and Heading 2106<br/>Text to codes 2106, 2106 90, 2106 90 92, 85<br/> Lab Advice R24A0011<br/> Renewal of IENEN004-2023-BTI266', '이슈장소_eng': 'Nenagh, Co. Tipperary, Ireland', '키워드_eng': 'PUT UP FOR RETAIL SALE <br/>VITAMINS <br/>CAPSULES <br/>FOR GENERAL USE <br/>BRAIN <br/>FATTY ACIDS <br/>FOR CHILDREN', '관련 이미지_eng': [], '기준년도_kor': '2024', '참조번호_kor': 'IEBTIIENEN004-2024-BTI72', '시행일자_kor': '2024-03-06', '결정세번_kor': '2106909285************', '물품설명_kor': '오메가 3 어유가 풍부한 씹을 수 있는 캡슐. 이 캡슐은 뇌 기능과 집중력을 향상시키고 전반적인 건강과 웰빙을 유지하는 데 도움이 됩니다. 각 캡슐에는 오메가-3 필수 지방산인 EHA와 DHA가 들어 있습니다. 또한 비타민 A, D, E도 들어 있습니다. 오렌지 맛으로 판매되며 소매용으로 판매됩니다. 용기에 60개가 들어 있습니다.', '분류사유_kor': 'GIR 1 및 6 제21장에 대한 주석 제21장에 대한 추가 주석(CN) 5 제21장과 제목 2106에 대한 HSEN 코드 2106, 2106 90, 2106 90 92, 85에 대한 텍스트 실험실 조언 R24A0011 IENEN004-2023-BTI266 갱신', '이슈장소_kor': 'Nenagh, Co. Tipperary, Ireland', '키워드_kor': '소매용으로 포장된 것  <br/>비타민  <br/>캡슐  <br/>일반적 사용을 위한 것  <br/>브레인  <br/>지방산  <br/>아동을 위한 것', '관련 이미지_kor': []}
# {'기준년도_org': '2024', '참조번호_org': 'XIBTI000000-2024-BTI114', '시행일자_org': '2024-09-04', '결정세번_org': '84842000**************', '물품설명_org': 'Mechanical seal faces used in various industrial applications to prevent leakage between rotating and stationary parts. These seal faces are crafted from sintered silicon due to properties allowing for thermal conductivity, resistance to wear and corrosion. They are ring shaped, of a graphite colour packaged sufficiently to protect them from damage when shipping. Sizes can be from 35mm to 200mm<br/>They are used specifically in a mechanical seal to prevent leakage. Due to the bespoke design, they can only ever be used in a mechanical seal.<br/>They are made of  sintered silicon, sintering process involves compacting silicon carbide powder under high temperature and pressure to create a dense, durable material with a fine, uniform microstructure. They are then machined to the drawing requirement.<br/>They are specifically designed and selected for the application.  The rings are very light in weight due to their low density. It also important to note, due to their design, they do not have another use except within a mechanical seal.', '분류사유_org': 'Classification has been determined in accordance with the following:-<br/>General Interpretative Rules (GIR)s:<br/><br/>GIR 1 has been used to classify this product by the terms of heading 8484 - Gaskets and similar joints of metal sheeting combined with other material or of two or more layers of metal; sets or assortments of gaskets and similar joints, dissimilar in composition, put up in pouches, envelopes or similar packings; mechanical seals<br/><br/>GIR 6 has been used to classify the goods to sub-heading 8484.20 ? Mechanical seals<br/>Harmonised Standard Explanatory Notes (HSENs) to heading 8484 ? Part C refers<br/>Considered classification to heading 8413 which covers pumps for liquids and parts therefor. Excluded from this heading as the goods are intended for various industrial applications and not specifically used as parts of pumps, therefore classified as parts of general use', '이슈장소_org': '', '키워드_org': 'SILICON CARBIDE<br/>GASKETS<br/>MECHANICAL<br/>RINGS, FORMS<br/>NON-METALS', '관련 이미지_org': [], '기준년도_eng': '2024', '참조번호_eng': 'XIBTI000000-2024-BTI114', '시행일자_eng': '2024-09-04', '결정세번_eng': '84842000**************', '물품설명_eng': 'Mechanical seal faces used in various industrial applications to prevent leakage between rotating and stationary parts. These seal faces are crafted from sintered silicon due to properties allowing for thermal conductivity, resistance to wear and corrosion. They are ring shaped, of a graphite colour packaged sufficiently to protect them from damage when shipping. Sizes can be from 35mm to 200mm<br/>They are used specifically in a mechanical seal to prevent leakage. Due to the bespoke design, they can only ever be used in a mechanical seal.<br/>They are made of  sintered silicon, sintering process involves compacting silicon carbide powder under high temperature and pressure to create a dense, durable material with a fine, uniform microstructure. They are then machined to the drawing requirement.<br/>They are specifically designed and selected for the application.  The rings are very light in weight due to their low density. It also important to note, due to their design, they do not have another use except within a mechanical seal.', '분류사유_eng': 'Classification has been determined in accordance with the following:-<br/>General Interpretative Rules (GIR)s:<br/><br/>GIR 1 has been used to classify this product by the terms of heading 8484 - Gaskets and similar joints of metal sheeting combined with other material or of two or more layers of metal; sets or assortments of gaskets and similar joints, dissimilar in composition, put up in pouches, envelopes or similar packings; mechanical seals<br/><br/>GIR 6 has been used to classify the goods to sub-heading 8484.20 ? Mechanical seals<br/>Harmonised Standard Explanat ...
# {'기준년도_org': '2024', '참조번호_org': 'XIBTI505064382', '시행일자_org': '2024-09-03', '결정세번_org': '3002120000************', '물품설명_org': 'BBMC (Buffy Coat Mononuclear Cells) -  A fraction of blood containing most of the white blood cells and platelets, separated from whole blood.<br/><br/>Peripheral Blood Mononuclear Cells (PBMCs) are a type of blood cell that plays a crucial role in the immune system. <br/><br/>Samples are collected from blood samples and usually packaged in sample collection tubes and in some occasions a reagent used to preserve the samples.', '분류사유_org': 'Classification has been determined in accordance with the following:- <br/>General Interpretative Rules (GIR)s<br/>GIR 1 has been used to classify this product by the terms of heading 3002 - Human blood; animal blood prepared for therapeutic, prophylactic or diagnostic uses; antisera, other blood fractions and immunological products, whether or not modified or obtained by means of biotechnological processes; vaccines, toxins, cultures of micro-organisms (excluding yeasts) and similar products; cell cultures, whether or not modified <br/>GIR 5b has been used to identify the type of packaging ? in test tubes or blood collection tubes <br/>GIR 6 has been used to classify the goods to subheading level 300212 - Antisera, other blood fractions and immunological products, whether or not modified or obtained by means of biotechnological processes; Antisera and other blood fractions<br/>HSEN to 3002', '이슈장소_org': '', '키워드_org': 'BLOOD FRACTIONS<br/>IN TUBES<br/>BLOOD<br/>AS LIQUID<br/>HUMAN BLOOD', '관련 이미지_org': [], '기준년도_eng': '2024', '참조번호_eng': 'XIBTI505064382', '시행일자_eng': '2024-09-03', '결정세번_eng': '3002120000************', '물품설명_eng': 'BBMC (Buffy Coat Mononuclear Cells) -  A fraction of blood containing most of the white blood cells and platelets, separated from whole blood.<br/><br/>Peripheral Blood Mononuclear Cells (PBMCs) are a type of blood cell that plays a crucial role in the immune system. <br/><br/>Samples are collected from blood samples and usually packaged in sample collection tubes and in some occasions a reagent used to preserve the samples.', '분류사유_eng': 'Classification has been determined in accordance with the following:- <br/>General Interpretative Rules (GIR)s<br/>GIR 1 has been used to classify this product by the terms of heading 3002 - Human blood; animal blood prepared for therapeutic, prophylactic or diagnostic uses; antisera, other blood fractions and immunological products, whether or not modified or obtained by means of biotechnological processes; vaccines, toxins, cultures of micro-organisms (excluding yeasts) and similar products; cell cultures, whether or not modified <br/>GIR 5b has been used to identify the type of packaging ? in test tubes or blood collection tubes <br/>GIR 6 has been used to classify the goods to subheading level 300212 - Antisera, other blood fractions and immunological products, whether or not modified or obtained by means of biotechnological processes; Antisera and other blood fractions<br/>HSEN to 3002', '이슈장소_eng': '', '키워드_eng': 'BLOOD FRACTIONS<br/>IN TUBES<br/>BLOOD<br/>AS LIQUID<br/>HUMAN BLOOD', '관련 이미지_eng': [], '기준년도_kor': '2024', '참조번호_kor': 'XIBTI505064382', '시행일자_kor': '2024-09-03', '결정세번_kor': '3002120000************', '물품설명_kor': 'BBMC(버피코트 단핵세포) - 전혈에서 분리된 대부분의 백혈구와 혈소판을 함유한 혈액 분획. 말초혈 단핵세포(PBMC)는 면역 체계에서 중요한 역할을 하는 혈액 세포의 한 종류입니다. 혈액 샘플에서 샘플을 채취하여 일반적으로 샘플 수집 튜브에 포장하고 어떤 경우에는 샘플을 보존하는 데 사용되는 시약을 포장합니다.', '분류사유_kor': '분류는 다음에 따라 결정되었습니다.- 일반 해석 규칙(GIR) GIR 1은 이 제품을 3002호의 용어로 분류하는 데 사용되었습니다.- 인간 혈액; 치료적, 예방적 또는 진단적 용도로 제조된 동물 혈액; 항체, 기타 혈액 분획 및 면역학적 제품(생명공학적 공정을 통해 변형 또는 획득되었는지 여부에 관계 없음); 백신, 독소, 미생물 배양(효모 제외) 및 이와 유사한 제품; 세포 배양(변형되었는지 여부에 관계 없음) GIR 5b는 시험관 또는 혈액 수집 튜브에 담긴 포장 유형을 식별하는 데 사용되었습니다.GIR 6은 제품을 하위 호 수준 300212로 분류하는 데 사용되었습니다.- 항체, 기타 혈액 분획 및 면역학적 제품(생명공학적 공정을 통해 변형 또는 획득되었는지 여부에 관계 없음); 항체 및 기타 혈액 분획 HSEN에서 3002까지', '이슈장소_kor': '', '키워드_kor': '피 분획<br/>관에서<br/>피<br/>액체로서<br/>사람의 피', '관련 이 ...
# {'기준년도_org': '2024', '참조번호_org': 'IEBTIIENEN004-2024-BTI83', '시행일자_org': '2024-03-06', '결정세번_org': '2106909285************', '물품설명_org': 'Food supplements (Omega 3-6-9) in the form of capsules<br/>It is for human consumption. These capsules are beneficial for cardiovascular health, brain function, healthy growth and<br/>development<br/>It is presented in packs of 60 capsules.', '분류사유_org': 'G.I.R 1 &amp; 6<br/>NOTES TO CHAPTER 21<br/>NOTES TO CHAPTER 21 AND HEADING 2106<br/>Additional Note 5 to Chapter 21<br/>TEXT TO CODE 2106, 210690, 21069092, 2106909285<br/>LAB ADVICE R24A0012', '이슈장소_org': 'NENAGH CO TIPPERARY', '키워드_org': 'FOR HUMAN CONSUMPTION <br/>GELATIN <br/>CAPSULES <br/>BRAIN <br/>FOOD SUPPLEMENTS <br/>DAIRY FREE', '관련 이미지_org': [], '기준년도_eng': '2024', '참조번호_eng': 'IEBTIIENEN004-2024-BTI83', '시행일자_eng': '2024-03-06', '결정세번_eng': '2106909285************', '물품설명_eng': 'Food supplements (Omega 3-6-9) in the form of capsules<br/>It is for human consumption. These capsules are beneficial for cardiovascular health, brain function, healthy growth and<br/>development<br/>It is presented in packs of 60 capsules.', '분류사유_eng': 'G.I.R 1 &amp; 6<br/>NOTES TO CHAPTER 21<br/>NOTES TO CHAPTER 21 AND HEADING 2106<br/>Additional Note 5 to Chapter 21<br/>TEXT TO CODE 2106, 210690, 21069092, 2106909285<br/>LAB ADVICE R24A0012', '이슈장소_eng': 'NENAGH CO TIPPERARY', '키워드_eng': 'FOR HUMAN CONSUMPTION <br/>GELATIN <br/>CAPSULES <br/>BRAIN <br/>FOOD SUPPLEMENTS <br/>DAIRY FREE', '관련 이미지_eng': [], '기준년도_kor': '2024', '참조번호_kor': 'IEBTIIENEN004-2024-BTI83', '시행일자_kor': '2024-03-06', '결정세번_kor': '2106909285************', '물품설명_kor': '캡슐 형태의 식품 보충제(오메가 3-6-9) 인간이 섭취하는 것입니다. 이 캡슐은 심혈관 건강, 뇌 기능, 건강한 성장과 발달에 유익합니다. 60캡슐 팩으로 제공됩니다.', '분류사유_kor': 'GIR 1 및 6 21장에 대한 주석 21장과 제목 2106에 대한 주석 21장에 대한 추가 주석 5 코드 2106, 210690, 21069092, 2106909285에 대한 텍스트 실험실 조언 R24A0012', '이슈장소_kor': 'NENAGH CO TIPPERARY', '키워드_kor': '식용을 위해 위한 것  <br/>제라틴  <br/>캡슐  <br/>브레인  <br/>FOOD보충제  <br/>자유로운 낙농업', '관련 이미지_kor': []}
# {'기준년도_org': '2024', '참조번호_org': 'XIBTI505064284', '시행일자_org': '2024-09-03', '결정세번_org': '2934999090************', '물품설명_org': 'DNA is a double-stranded molecule forming a double helix. Each strand is made up of nucleotides, which include a phosphate group, a sugar molecule (deoxyribose), and one of four nitrogenous bases: adenine (A), thymine (T), cytosine ⓒ, and guanine (G). <br/><br/>RNA is typically single-stranded and shorter than DNA. It consists of nucleotides that include a phosphate group, a sugar molecule (ribose), and one of four nitrogenous bases: adenine (A), uracil (U), cytosine ⓒ, and guanine (G)<br/><br/>Human RNA/DNA samples used for diagnostic testing, clinical and laboratory research. Usually packaged in sample collection tubes and in some occasions a reagent may be used to preserve RNA/DNA samples.  <br/><br/>DNA Samples: Typically collected from blood, saliva, or tissue samples.<br/><br/>RNA Samples: Often collected from blood or tissue samples, and require careful handling to prevent degradation.', '분류사유_org': 'Classification has been determined in accordance with the following:- <br/>General Interpretative Rules (GIR)s<br/>GIR 1 has been used to classify this product by the terms of heading 2934 - Nucleic acids and their salts, whether or not chemically defined; other heterocyclic compounds <br/>GIR 5b has been used to identify the type of packaging ? in test tubes or slides <br/>GIR 6 has been used to classify the goods to subheading level 293499 ? Other than elsewhere specified <br/>CN code 29349990 - Other than chlorprothixene (inn); thenalidine (inn) and its tartrates and maleates; furazolidone (inn); 7-aminocephalosporanic acid; salts and esters of (6r,7r)-3-acetoxymethyl-7-[(r)-2-formyloxy-2-phenylacetamido]-8-oxo-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylic acid; 1-[2-(1.3-dioxan-2-yl)ethyl]-2-methylpyridinium bromide <br/>Taric code 2934999090 ? Other than elsewhere specified<br/>HSEN to 2934', '이슈장소_org': '', '키워드_org': 'LABORATORY TUBES<br/>FOR TESTING<br/>NULEIC ACIDS AND SALTS<br/>ORGANIC COMPOUNDS<br/>HETEROCYLIC COMPOUNDS<br/>FOR DIAGNOSTIC USE', '관련 이미지_org': [], '기준년도_eng': '2024', '참조번호_eng': 'XIBTI505064284', '시행일자_eng': '2024-09-03', '결정세번_eng': '2934999090************', '물품설명_eng': 'DNA is a double-stranded molecule forming a double helix. Each strand is made up of nucleotides, which include a phosphate group, a sugar molecule (deoxyribose), and one of four nitrogenous bases: adenine (A), thymine (T), cytosine ⓒ, and guanine (G). <br/><br/>RNA is typically single-stranded and shorter than DNA. It consists of nucleotides that include a phosphate group, a sugar molecule (ribose), and one of four nitrogenous bases: adenine (A), uracil (U), cytosine ⓒ, and guanine (G)<br/><br/>Human RNA/DNA samples used for diagnostic testing, clinical and laboratory research. Usually packaged in sample collection tubes and in some occasions a reagent may be used to preserve RNA/DNA samples.  <br/><br/>DNA Samples: Typically collected from blood, saliva, or tissue samples.<br/><br/>RNA Samples: Often collected from blood or tissue samples, and require careful handling to prevent degradation.', '분류사유_eng': 'Classification has been determined in accordance with the following:- <br/>General Interpretative Rules (GIR)s<br/>GIR 1 has been used to classify this product by the terms of heading 2934 - Nucleic acids and their salts, whether or not chemically defined; other heterocyclic compounds <br/>GIR 5b has been used to identify the type of packaging ? in test tubes or slides <br/>GIR 6 has been used to classify the goods to subheading level 293499 ? Other than elsewhere specified <br/>CN code 29349990 - Other than chlorprothixene (inn); thenalidine (inn) and its tartrates and maleates; furazolidone (inn); 7-aminocephalosporanic acid; salts and esters of (6r,7r)-3-acetoxymethyl-7-[(r)-2-formyloxy-2-phenylacetamido]-8-oxo-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylic acid; 1-[2-(1.3-dioxan-2-yl)ethyl]-2- ...
# {'기준년도_org': '2024', '참조번호_org': 'IEBTIIENEN004-2024-BTI81', '시행일자_org': '2024-03-05', '결정세번_org': '8528521000************', '물품설명_org': 'A 14" LCD COLOUR MONITOR, WITH A SCREEN RESOLUTION OF 2240 X 1400 PIXELS, WITH DIMENSIONS OF: 314.8MM (W) X 223.1MM (H) X 14.1MM (D), CONTRAST RATIO OF 1500:1 (TYPICAL), BRIGHTNESS OF 300CD/M2 (TYPICAL), 16.7M COLOURS, IPS PANEL TECHNOLOGY. PIXEL PITCH 0.135MM.<br/><br/>INPUT/OUTPUT CONNECTIONS: 2 X USB C, NO AUDIO OUT JACK, NO SPEAKERS. EXTERNAL POWER SUPPLY. MOUNTED ON AN ADJUSTABLE STAND.  THE MONITOR CAN DISPLAY VIDEO FROM ANY DEVICE THAT HAS VIDEO OUT VIA USB C CAPABILITY. THE MONITOR DOES NOT HAVE ANY TV SIGNAL RECEPTION CAPABILITY, IT HAS NO ONBOARD TUNER.', '분류사유_org': 'GENERAL RULES 1 AND 6 FOR THE INTERPRETATION OF THE COMBINED NOMENCLATURE.<br/>CHAPTER 84, NOTE 6 (D) (V).<br/>HSEN TO HEADING 8528 (A).<br/>THE TEXT OF CN CODES 8528, 8528 52 AND 8528 52 10.', '이슈장소_org': 'NENAGH', '키워드_org': 'LCD <br/>WITH AUDIO INPUT <br/>WITH AUDIO OUTPUT <br/>WITH LCD DISPLAY <br/>LCD MONITOR <br/>FOR MONITORING VOLTAGE <br/>MONITORS <br/>COLOUR MONITORS', '관련 이미지_org': [], '기준년도_eng': '2024', '참조번호_eng': 'IEBTIIENEN004-2024-BTI81', '시행일자_eng': '2024-03-05', '결정세번_eng': '8528521000************', '물품설명_eng': 'A 14" LCD COLOUR MONITOR, WITH A SCREEN RESOLUTION OF 2240 X 1400 PIXELS, WITH DIMENSIONS OF: 314.8MM (W) X 223.1MM (H) X 14.1MM (D), CONTRAST RATIO OF 1500:1 (TYPICAL), BRIGHTNESS OF 300CD/M2 (TYPICAL), 16.7M COLOURS, IPS PANEL TECHNOLOGY. PIXEL PITCH 0.135MM.<br/><br/>INPUT/OUTPUT CONNECTIONS: 2 X USB C, NO AUDIO OUT JACK, NO SPEAKERS. EXTERNAL POWER SUPPLY. MOUNTED ON AN ADJUSTABLE STAND.  THE MONITOR CAN DISPLAY VIDEO FROM ANY DEVICE THAT HAS VIDEO OUT VIA USB C CAPABILITY. THE MONITOR DOES NOT HAVE ANY TV SIGNAL RECEPTION CAPABILITY, IT HAS NO ONBOARD TUNER.', '분류사유_eng': 'GENERAL RULES 1 AND 6 FOR THE INTERPRETATION OF THE COMBINED NOMENCLATURE.<br/>CHAPTER 84, NOTE 6 (D) (V).<br/>HSEN TO HEADING 8528 (A).<br/>THE TEXT OF CN CODES 8528, 8528 52 AND 8528 52 10.', '이슈장소_eng': 'NENAGH', '키워드_eng': 'LCD <br/>WITH AUDIO INPUT <br/>WITH AUDIO OUTPUT <br/>WITH LCD DISPLAY <br/>LCD MONITOR <br/>FOR MONITORING VOLTAGE <br/>MONITORS <br/>COLOUR MONITORS', '관련 이미지_eng': [], '기준년도_kor': '2024', '참조번호_kor': 'IEBTIIENEN004-2024-BTI81', '시행일자_kor': '2024-03-05', '결정세번_kor': '8528521000************', '물품설명_kor': '2240 X 1400픽셀의 화면 해상도를 갖춘 14인치 LCD 컬러 모니터, 치수: 314.8mm(폭) X 223.1mm(높이) X 14.1mm(깊이), 1500:1(일반), 300CD/M2(일반)의 밝기, 16.7M 색상, IPS 패널 기술. 픽셀 피치 0.135mm. 입/출력 연결: 2개의 USB C, 오디오 출력 잭 없음, 스피커 없음. 외부 전원 공급 장치. 조절 가능한 스탠드에 장착. 모니터는 USB C를 통해 비디오 출력이 있는 모든 장치의 비디오를 표시할 수 있습니다. 기능. 모니터에는 TV 신호 수신 기능이 없으며 튜너가 내장되어 있지 않습니다.', '분류사유_kor': '결합 명명법 해석을 위한 일반 규칙 1 및 6. 제84장, 주 6(D)(V). HSEN에서 8528(A) 항목으로. CN 코드 8528, 8528 52 및 8528 52 10의 텍스트.', '이슈장소_kor': 'NENAGH', '키워드_kor': 'LCD  <br/>음성 입력으로  <br/>음성 출력으로  <br/>LCD 화면으로  <br/>LCD 모니터  <br/>전압 모니터링을 위한 것  <br/>모니터  <br/>색 영상 감시 장치', '관련 이미지_kor': []}
# {'기준년도_org': '2024', '참조번호_org': 'IEBTIIENEN004-2024-BTI28', '시행일자_org': '2024-03-05', '결정세번_org': '8428909080************', '물품설명_org': 'AIRCRAFT ENGINE STAND, WHICH IS USED FOR TRANSPORTING AND HOLDING AIRCRAFT ENGINES. THE STAND CAN ALSO HAVE THE FUNCTION OF ROTATING. THE PURPOSE OF THE STAND IS FOR MAINTENANCE OR INSPECTION OF THE ENGINE.', '분류사유_org': 'GENERAL RULES 1 AND 6 FOR THE INTERPRETATION OF THE COMBINED NOMENCLATURE.<br/>HARMONISED SYSTEM EXPLANATORY NOTES (HSEN) TO 8428 (III).<br/>TEXT TO TARIC CODE 8428, 8528 90, 8428 90 90 AND 8428 90 90 80.', '이슈장소_org': 'NENAGH', '키워드_org': 'AIRCRAFT <br/>STAND <br/>STANDS <br/>FOR ENGINES', '관련 이미지_org': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241202-0000598483995Ks8', '/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241202-000059848403ZprM', '/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241202-000059848414NCq9'], '기준년도_eng': '2024', '참조번호_eng': 'IEBTIIENEN004-2024-BTI28', '시행일자_eng': '2024-03-05', '결정세번_eng': '8428909080************', '물품설명_eng': 'AIRCRAFT ENGINE STAND, WHICH IS USED FOR TRANSPORTING AND HOLDING AIRCRAFT ENGINES. THE STAND CAN ALSO HAVE THE FUNCTION OF ROTATING. THE PURPOSE OF THE STAND IS FOR MAINTENANCE OR INSPECTION OF THE ENGINE.', '분류사유_eng': 'GENERAL RULES 1 AND 6 FOR THE INTERPRETATION OF THE COMBINED NOMENCLATURE.<br/>HARMONISED SYSTEM EXPLANATORY NOTES (HSEN) TO 8428 (III).<br/>TEXT TO TARIC CODE 8428, 8528 90, 8428 90 90 AND 8428 90 90 80.', '이슈장소_eng': 'NENAGH', '키워드_eng': 'AIRCRAFT <br/>STAND <br/>STANDS <br/>FOR ENGINES', '관련 이미지_eng': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241202-0000598483995Ks8', '/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241202-000059848403ZprM', '/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241202-000059848414NCq9'], '기준년도_kor': '2024', '참조번호_kor': 'IEBTIIENEN004-2024-BTI28', '시행일자_kor': '2024-03-05', '결정세번_kor': '8428909080************', '물품설명_kor': '항공기 엔진 스탠드는 항공기 엔진을 운반하고 보관하는 데 사용됩니다. 스탠드는 회전 기능도 가질 수 있습니다. 스탠드의 목적은 엔진의 유지 관리 또는 검사입니다.', '분류사유_kor': '결합 명명법 해석을 위한 일반 규칙 1 및 6. 8428(III)에 대한 조화된 시스템 설명 노트(HSEN). TARIC 코드 8428, 8528 90, 8428 90 90 및 8428 90 90 80에 대한 텍스트.', '이슈장소_kor': 'NENAGH', '키워드_kor': '항공기  <br/>스탠드  <br/>스탠드  <br/>엔진을 위한 것', '관련 이미지_kor': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241202-0000598483995Ks8', '/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241202-000059848403ZprM', '/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241202-000059848414NCq9']}
# {'기준년도_org': '2024', '참조번호_org': 'IEBTIIENEN004-2024-BTI51', '시행일자_org': '2024-03-05', '결정세번_org': '6114300000************', '물품설명_org': 'Ladies Cami top is made of man made knitted fabric, reaching down to the waist, with a deep V-neckline and cut and sew bra cup with no support.<br/>The item has thin adjustable straps and lace trim on the hem.', '분류사유_org': 'G.I.R 1 &amp; 6<br/>Notes to Chapter 61<br/>HSEN to Chapter 61 and heading 6114<br/>Texts to code 6114, 6114 30, 6114 30 00, 6114 30 00 00', '이슈장소_org': 'Nenagh, Co Tipperary', '키워드_org': 'ADJUSTABLE <br/>LACE <br/>STRAPS <br/>KNITTED FABRICS <br/>WITH HEM <br/>CLOTHING ACCESSORIES', '관련 이미지_org': [], '기준년도_eng': '2024', '참조번호_eng': 'IEBTIIENEN004-2024-BTI51', '시행일자_eng': '2024-03-05', '결정세번_eng': '6114300000************', '물품설명_eng': 'Ladies Cami top is made of man made knitted fabric, reaching down to the waist, with a deep V-neckline and cut and sew bra cup with no support.<br/>The item has thin adjustable straps and lace trim on the hem.', '분류사유_eng': 'G.I.R 1 &amp; 6<br/>Notes to Chapter 61<br/>HSEN to Chapter 61 and heading 6114<br/>Texts to code 6114, 6114 30, 6114 30 00, 6114 30 00 00', '이슈장소_eng': 'Nenagh, Co Tipperary', '키워드_eng': 'ADJUSTABLE <br/>LACE <br/>STRAPS <br/>KNITTED FABRICS <br/>WITH HEM <br/>CLOTHING ACCESSORIES', '관련 이미지_eng': [], '기준년도_kor': '2024', '참조번호_kor': 'IEBTIIENEN004-2024-BTI51', '시행일자_kor': '2024-03-05', '결정세번_kor': '6114300000************', '물품설명_kor': '레이디스 캐미 탑은 인조 니트 원단으로 만들어졌으며 허리까지 내려오고 깊은 V넥라인과 지지대가 없는 컷 앤 소우 브라 컵이 있습니다. 이 품목은 얇은 조절 가능한 스트랩과 밑단에 레이스 트림이 있습니다.', '분류사유_kor': 'GIR 1 및 6 61장에 대한 주석 HSEN 61장 및 6114 제목 코드 6114, 6114 30, 6114 30 00, 6114 30 00 00에 대한 텍스트', '이슈장소_kor': 'Nenagh, Co Tipperary', '키워드_kor': '조정가능한 것  <br/>레이스  <br/>스트랩  <br/>편직물  <br/>옷단으로  <br/>의류 부속품', '관련 이미지_kor': []}
# {'기준년도_org': '2024', '참조번호_org': 'XIBTI505064186', '시행일자_org': '2024-09-03', '결정세번_org': '0511998590************', '물품설명_org': 'Non-Therapeutic Human Tissue, Bone Marrow, FFPE blocks, Slides &amp; fresh tissue.<br/><br/>Bone Marrow - Soft, spongy tissue found inside bones, responsible for producing blood cells. Bone marrow biopsies are used to diagnose and monitor blood disorders, cancers like leukemia and lymphoma, and other conditions affecting blood cell production.<br/><br/>FFPE Blocks- Tissue samples preserved by fixing in formalin and embedding in paraffin wax.<br/><br/>Slides - Thin sections of tissue mounted on glass slides for microscopic examination.<br/><br/>Fresh Tissue - Tissue samples collected and used without preservation to maintain their physiological state.<br/><br/><br/>All samples Used for diagnostic, clinical and laboratory research and some occasions for therapeutic use.', '분류사유_org': 'Classification has been determined in accordance with the following:- <br/>General interpretative rules (GIR)s: <br/>GIR 1 has been used to classify this product by the terms of heading 0511 - animal products not elsewhere specified or included; dead animals of chapter 1 or 3, unfit for human consumption <br/>GIR 5b has been used to identify the type of packaging - either sample collection tubes, slides, blocks.<br/>GIR 6 has been used to classify the goods to subheading level 051199 - other than specified elsewhere in this heading <br/>CN code 05119985 - other than specified elsewhere in this heading <br/>Taric code 0511998590 other than elsewhere in the subheading<br/>Notes (HSEN)’s to chapter heading 0511<br/>Note (A) to HSEN 30.01', '이슈장소_org': '', '키워드_org': 'FOR LABORATORY USE<br/>FOR DIAGNOSTIC USE<br/>UNFIT FOR HUMAN CONSUMPTION<br/>FOR SCIENTIFIC RESEARCH<br/>OF HUMAN ORIGIN', '관련 이미지_org': [], '기준년도_eng': '2024', '참조번호_eng': 'XIBTI505064186', '시행일자_eng': '2024-09-03', '결정세번_eng': '0511998590************', '물품설명_eng': 'Non-Therapeutic Human Tissue, Bone Marrow, FFPE blocks, Slides &amp; fresh tissue.<br/><br/>Bone Marrow - Soft, spongy tissue found inside bones, responsible for producing blood cells. Bone marrow biopsies are used to diagnose and monitor blood disorders, cancers like leukemia and lymphoma, and other conditions affecting blood cell production.<br/><br/>FFPE Blocks- Tissue samples preserved by fixing in formalin and embedding in paraffin wax.<br/><br/>Slides - Thin sections of tissue mounted on glass slides for microscopic examination.<br/><br/>Fresh Tissue - Tissue samples collected and used without preservation to maintain their physiological state.<br/><br/><br/>All samples Used for diagnostic, clinical and laboratory research and some occasions for therapeutic use.', '분류사유_eng': 'Classification has been determined in accordance with the following:- <br/>General interpretative rules (GIR)s: <br/>GIR 1 has been used to classify this product by the terms of heading 0511 - animal products not elsewhere specified or included; dead animals of chapter 1 or 3, unfit for human consumption <br/>GIR 5b has been used to identify the type of packaging - either sample collection tubes, slides, blocks.<br/>GIR 6 has been used to classify the goods to subheading level 051199 - other than specified elsewhere in this heading <br/>CN code 05119985 - other than specified elsewhere in this heading <br/>Taric code 0511998590 other than elsewhere in the subheading<br/>Notes (HSEN)’s to chapter heading 0511<br/>Note (A) to HSEN 30.01', '이슈장소_eng': '', '키워드_eng': 'FOR LABORATORY USE<br/>FOR DIAGNOSTIC USE<br/>UNFIT FOR HUMAN CONSUMPTION<br/>FOR SCIENTIFIC RESEARCH<br/>OF HUMAN ORIGIN', '관련 이미지_eng': [], '기준년도_kor': '2024', '참조번호_kor': 'XIBTI505064186', '시행일자_kor': '2024-09-03', '결정세번_kor': '0511998590************', '물품설명_kor': '비치료적 인체 조직, 골수, FFPE 블록, 슬라이드 및 신선한 조직. 골수 - 뼈 내부에서 발견되는 부드럽고 해면 같은 조직으로, 혈액 세포를 생성합니다. 골수 생검은 혈액 질환, 백혈병 및 림프종과 같은 암, 혈액 세포 생성에 영향을 미치는 기타 질환을 진단하고 모니터링하는 데 사용됩니다. FFPE 블록 - 포르말린에 고정하고 파라핀 왁스에 포매 ...
# {'기준년도_org': '2024', '참조번호_org': 'IEBTIIENEN004-2024-BTI59', '시행일자_org': '2024-03-04', '결정세번_org': '2106909285************', '물품설명_org': 'Food supplement in the form of capsules.<br/>The capsules are specially formulated to provide vital nutrients required for healthy looking hair. It helps nurture the texture, thickness and colour of the hair.<br/>They are rich in B Vitamins and Essential Amino Acids.<br/>It is suitable for men and women and is available in 2 different pack sizes, a 30 pack and 90 pack.', '분류사유_org': 'G.I.R 1 &amp; 6<br/>Notes to Chapter 21<br/>Additional note 5 to Chapter 21<br/>HSEN to Chapter 21 and Heading 2106<br/>Text to Codes 2106, 2106 90, 2106 90 96 &amp; 2106 90 96 85<br/>Lab Advice R24A0010', '이슈장소_org': 'Nenagh, Co. Tipperary, Ireland', '키워드_org': 'VITAMINS <br/>FOOD SUPPLEMENTS <br/>HAIR <br/>CAPSULES <br/>PUT UP IN MEASURED DOSES <br/>PUT UP FOR RETAIL SALE', '관련 이미지_org': [], '기준년도_eng': '2024', '참조번호_eng': 'IEBTIIENEN004-2024-BTI59', '시행일자_eng': '2024-03-04', '결정세번_eng': '2106909285************', '물품설명_eng': 'Food supplement in the form of capsules.<br/>The capsules are specially formulated to provide vital nutrients required for healthy looking hair. It helps nurture the texture, thickness and colour of the hair.<br/>They are rich in B Vitamins and Essential Amino Acids.<br/>It is suitable for men and women and is available in 2 different pack sizes, a 30 pack and 90 pack.', '분류사유_eng': 'G.I.R 1 &amp; 6<br/>Notes to Chapter 21<br/>Additional note 5 to Chapter 21<br/>HSEN to Chapter 21 and Heading 2106<br/>Text to Codes 2106, 2106 90, 2106 90 96 &amp; 2106 90 96 85<br/>Lab Advice R24A0010', '이슈장소_eng': 'Nenagh, Co. Tipperary, Ireland', '키워드_eng': 'VITAMINS <br/>FOOD SUPPLEMENTS <br/>HAIR <br/>CAPSULES <br/>PUT UP IN MEASURED DOSES <br/>PUT UP FOR RETAIL SALE', '관련 이미지_eng': [], '기준년도_kor': '2024', '참조번호_kor': 'IEBTIIENEN004-2024-BTI59', '시행일자_kor': '2024-03-04', '결정세번_kor': '2106909285************', '물품설명_kor': '캡슐 형태의 식품 보충제입니다. 캡슐은 건강해 보이는 머리카락에 필요한 필수 영양소를 제공하도록 특별히 제조되었습니다. 머리카락의 질감, 두께 및 색상을 키우는 데 도움이 됩니다. 비타민 B와 필수 아미노산이 풍부합니다. 남성과 여성 모두에게 적합하며 30팩과 90팩의 두 가지 팩 크기로 제공됩니다.', '분류사유_kor': 'GIR 1 및 6 21장에 대한 주석 21장에 대한 추가 주석 5 21장과 2106장에 대한 HSEN 및 제목 2106 코드에 대한 텍스트 2106, 2106 90, 2106 90 96 및 2106 90 96 85 실험실 조언 R24A0010', '이슈장소_kor': 'Nenagh, Co. Tipperary, Ireland', '키워드_kor': '비타민  <br/>FOOD보충제  <br/>머리카락  <br/>캡슐  <br/>측정 광량 선량에 포장된 것  <br/>소매용', '관련 이미지_kor': []}
# ...
# {'기준년도_org': '2023', '참조번호_org': 'IEBTIIENEN004-2023-BTI552', '시행일자_org': '2023-10-18', '결정세번_org': '21069098497015********', '물품설명_org': 'Chaga Mushroom Extract 30% Polysaccharides UV - (fruit body)<br/>It is a food grade supplement normally added to tablets/capsules.<br/>This product is presented as a dark brown coloured fine powder.<br/>The bulk powder is distributed in 25kg drums.', '분류사유_org': 'G.I.R 1 &amp; 6<br/>NOTES TO CHAPTER 21<br/>NOTES TO CHAPTER 21 AND HEADING 2106<br/>TEXT TO CODE 2106, 210690, 21069098, 2106909849<br/>LAB ADVICE R23A0147', '이슈장소_org': 'NENAGH CO TIPPERARY', '키워드_org': 'BROWN <br/>IN BULK <br/>POLYSACCHARIDES <br/>EXTRACT <br/>MUSHROOMS <br/>FINE POWDER', '관련 이미지_org': [], '기준년도_eng': '2023', '참조번호_eng': 'IEBTIIENEN004-2023-BTI552', '시행일자_eng': '2023-10-18', '결정세번_eng': '21069098497015********', '물품설명_eng': 'Chaga Mushroom Extract 30% Polysaccharides UV - (fruit body)<br/>It is a food grade supplement normally added to tablets/capsules.<br/>This product is presented as a dark brown coloured fine powder.<br/>The bulk powder is distributed in 25kg drums.', '분류사유_eng': 'G.I.R 1 &amp; 6<br/>NOTES TO CHAPTER 21<br/>NOTES TO CHAPTER 21 AND HEADING 2106<br/>TEXT TO CODE 2106, 210690, 21069098, 2106909849<br/>LAB ADVICE R23A0147', '이슈장소_eng': 'NENAGH CO TIPPERARY', '키워드_eng': 'BROWN <br/>IN BULK <br/>POLYSACCHARIDES <br/>EXTRACT <br/>MUSHROOMS <br/>FINE POWDER', '관련 이미지_eng': [], '기준년도_kor': '2023', '참조번호_kor': 'IEBTIIENEN004-2023-BTI552', '시행일자_kor': '2023-10-18', '결정세번_kor': '21069098497015********', '물품설명_kor': '차가버섯 추출물 30% 폴리사카라이드 UV - (자실체) 일반적으로 정제/캡슐에 첨가되는 식품 등급 보충제입니다. 이 제품은 짙은 갈색의 미세 분말로 제공됩니다. 벌크 분말은 25kg 드럼에 분배됩니다.', '분류사유_kor': 'GIR 1 및 6 챕터 21에 대한 참고 사항 챕터 21 및 제목 2106에 대한 참고 사항 코드 2106, 210690, 21069098, 2106909849에 대한 텍스트 실험실 조언 R23A0147', '이슈장소_kor': 'NENAGH CO TIPPERARY', '키워드_kor': '브라운  <br/>대량으로  <br/>폴리사카라이드  <br/>엑스  <br/>버섯  <br/>미분', '관련 이미지_kor': []}
# {'기준년도_org': '2023', '참조번호_org': 'IEBTIIENEN004-2023-BTI560', '시행일자_org': '2023-10-17', '결정세번_org': '85444290**************', '물품설명_org': 'Insulated electrical cable.<br/>Equipped with a type USB C connector at both ends.<br/>For a voltage of 5 VDC.<br/>With a length of 1.5m.<br/>Rugged, braided Kevlar cable.<br/>Intended for connecting and charging devices and for data transfer between the connected devices.<br/>Compatible with USB C devices.', '분류사유_org': 'GIR 1 and 6<br/>HSEN To Heading 8544<br/>Text to Code 8544, 8544 42, 8544 42 90, 8544 42 90 90', '이슈장소_org': 'Nenagh', '키워드_org': 'CABLES <br/>INSULATED <br/>USB CONNECTORS <br/>ELECTRIC <br/>FOR DATA', '관련 이미지_org': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241202-0000598474094rPx'], '기준년도_eng': '2023', '참조번호_eng': 'IEBTIIENEN004-2023-BTI560', '시행일자_eng': '2023-10-17', '결정세번_eng': '85444290**************', '물품설명_eng': 'Insulated electrical cable.<br/>Equipped with a type USB C connector at both ends.<br/>For a voltage of 5 VDC.<br/>With a length of 1.5m.<br/>Rugged, braided Kevlar cable.<br/>Intended for connecting and charging devices and for data transfer between the connected devices.<br/>Compatible with USB C devices.', '분류사유_eng': 'GIR 1 and 6<br/>HSEN To Heading 8544<br/>Text to Code 8544, 8544 42, 8544 42 90, 8544 42 90 90', '이슈장소_eng': 'Nenagh', '키워드_eng': 'CABLES <br/>INSULATED <br/>USB CONNECTORS <br/>ELECTRIC <br/>FOR DATA', '관련 이미지_eng': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241202-0000598474094rPx'], '기준년도_kor': '2023', '참조번호_kor': 'IEBTIIENEN004-2023-BTI560', '시행일자_kor': '2023-10-17', '결정세번_kor': '85444290**************', '물품설명_kor': '절연 전기 케이블. 양쪽 끝에 USB C형 커넥터가 장착되어 있습니다. 전압은 5 VDC입니다. 길이는 1.5m입니다. 견고한 브레이디드 케블라 케이블입니다. 장치를 연결하고 충전하고 연결된 장치 간의 데이터 전송을 위해 고안되었습니다. USB C 장치와 호환됩니다.', '분류사유_kor': 'GIR 1 및 6 HSEN 제목 8544 텍스트 코드 8544, 8544 42, 8544 42 90, 8544 42 90 90', '이슈장소_kor': 'Nenagh', '키워드_kor': '케이블  <br/>절연된 것  <br/>USB 커넥터  <br/>ELECTRIC  <br/>데이터를 위한 것', '관련 이미지_kor': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241202-0000598474094rPx']}
# {'기준년도_org': '2024', '참조번호_org': 'ESBTIESBTI2024SOL711', '시행일자_org': '2024-09-30', '결정세번_org': '73089098**************', '물품설명_org': 'Columnas/postes de acero de 8.500 mm de altura. Están formadas por una base plana circular (con diámetros exteriores de 610 o 630 mm e interiores de 320 y 375 mm) provista de agujeros a intervalos regulares en su contorno. De esta base sobresale una columna troncocónica provista de ventana de registro, chapa identificativa, taladro para pararrayos y una ventana "feeder". <br/>Se presentan en una única pieza embalados de forma individual.<br/>Según declaración del solicitante se usarán para sostener las catenarias de alimentación de trenes.', '분류사유_org': 'RGI 1 (Nota 3 de la Sección XV, Nota 1 d) del capítulo 72) y 6 y texto de los códigos de NC 7308 y 7308 90 98', '이슈장소_org': '', '키워드_org': 'OF STEEL<br/>WIDE AT THE BOTTOM<br/>OF TUBULAR STEEL<br/>CONIC<br/>FOR HANGING UP', '관련 이미지_org': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241120-000059682440wxlt'], '기준년도_eng': '2024', '참조번호_eng': 'ESBTIESBTI2024SOL711', '시행일자_eng': '2024-09-30', '결정세번_eng': '73089098**************', '물품설명_eng': "Steel columns/posts 8,500 mm high. They consist of a flat circular base (with external diameters of 610 or 630 mm and internal diameters of 320 and 375 mm) provided with holes at regular intervals around its perimeter. A truncated cone-shaped column with a registration window, identification plate, lightning rod drill and a feeder window protrudes from this base. They are presented in a single piece, individually packaged. According to the applicant's declaration, they will be used to support the catenaries that feed trains.", '분류사유_eng': 'RGI 1 (Note 3 to Section XV, Note 1 d) to Chapter 72) and 6 and text of CN codes 7308 and 7308 90 98', '이슈장소_eng': '', '키워드_eng': 'OF STEEL<br/>WIDE AT THE BOTTOM<br/>OF TUBULAR STEEL<br/>CONIC<br/>FOR HANGING UP', '관련 이미지_eng': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241120-000059682440wxlt'], '기준년도_kor': '2024', '참조번호_kor': 'ESBTIESBTI2024SOL711', '시행일자_kor': '2024-09-30', '결정세번_kor': '73089098**************', '물품설명_kor': '8,500mm 높이의 강철 기둥/포스트. 이는 윤곽 주위에 일정한 간격으로 구멍이 있는 평평한 원형 베이스(외부 직경이 610 또는 630mm이고 내부 직경이 320 및 375mm)로 구성됩니다. 이 베이스에는 등록 창, 식별판, 피뢰침용 구멍 및 "피더" 창이 있는 잘린 원뿔형 기둥이 돌출되어 있습니다. 단일 제품으로 개별 포장되어 제공됩니다. 신청자의 진술에 따르면, 이는 열차 동력 전선을 지원하는 데 사용될 것입니다.', '분류사유_kor': '통칙 1(제15부 주3, 제72류 주1d) 및 통칙 6과 CN 코드 7308 및 7308의 본문 90 98', '이슈장소_kor': '', '키워드_kor': '강의 것<br/>사실은 넓은 것<br/>관형 강철의 것<br/>CONIC<br/>개서', '관련 이미지_kor': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241120-000059682440wxlt']}
# {'기준년도_org': '2024', '참조번호_org': 'ATBTI2024000324-DEC', '시행일자_org': '2024-09-30', '결정세번_org': '86080000**************', '물품설명_org': 'Steuergerät für Parkplätze oder Parkhäuser in Form einer Säule mit den Abmessungen von 354 mm Breite x 1345 mm Höhe x 456 Tiefe mit einer Erfassungseinheit für Barcode bzw. RFID von Parktickets, einem Display (wahlweise) mit Ansteuerung von Parkschranken oder Rolltoren, etc, um Ein-/Ausfahrten in oder aus abgesperrten Bereichen zu ermöglichen; in den Ausführungen Einfahrt, Ausfahrt und jeweils RHD für Linksverkehr.', '분류사유_org': 'Allgemeine Vorschriften für die Auslegung der Kombinierten Nomenklatur (AV) 1 und 6;<br/>Anmerkung 1, lit. c zu Kapitel 86 (trifft nicht zu);<br/>Anmerkung 3, lit. b zu Kapitel 86<br/>Erläuterungen zum HS zu Kapitel 86, Allgemeines, Buchstabe D;<br/>Erläuterungen zum HS zu Position 8608.', '이슈장소_org': 'Wien', '키워드_org': 'BARRIERS<br/>TRAFFIC CONTROL EQUIPMENT<br/>PILLARS<br/>WIDE<br/>CIRCULAR SHAPED', '관련 이미지_org': [], '기준년도_eng': '2024', '참조번호_eng': 'ATBTI2024000324-DEC', '시행일자_eng': '2024-09-30', '결정세번_eng': '86080000**************', '물품설명_eng': 'Control unit for parking lots or parking garages in the form of a column with dimensions of 354 mm wide x 1345 mm high x 456 mm deep with a recording unit for barcode or RFID of parking tickets, a display (optional) with control of parking barriers or roller doors, etc., to enable entry/exit into or from closed areas; in the versions entrance, exit and RHD for left-hand traffic.', '분류사유_eng': 'General rules for the interpretation of the Combined Nomenclature (GC) 1 and 6; Note 1, letter c to Chapter 86 (not applicable); Note 3, letter b to Chapter 86 HS Explanatory Notes to Chapter 86, General, paragraph D; HS Explanatory Notes to heading 8608.', '이슈장소_eng': 'Wien', '키워드_eng': 'BARRIERS<br/>TRAFFIC CONTROL EQUIPMENT<br/>PILLARS<br/>WIDE<br/>CIRCULAR SHAPED', '관련 이미지_eng': [], '기준년도_kor': '2024', '참조번호_kor': 'ATBTI2024000324-DEC', '시행일자_kor': '2024-09-30', '결정세번_kor': '86080000**************', '물품설명_kor': '주차 티켓의 바코드 또는 RFID용 기록 장치, 주차 제어 기능이 있는 디스플레이(옵션)를 갖춘 폭 354mm x 높이 1345mm x 깊이 456mm 크기의 기둥 형태의 주차 공간 또는 주차장용 제어 장치 장벽이나 롤러 도어 등 -/격리된 구역으로 들어가거나 나갈 수 있도록 하기 위해; 좌측 통행을 위한 입구, 출구 및 RHD 버전.', '분류사유_kor': '결합명명법(AV) 1과 6의 해석을 위한 일반 규칙 제86류 주 1 c(해당되지 않음); 제86류의 주 3, 문자 b HS에 대한 제86류 일반, 문자 D의 설명; 위치 8608에 대한 HS에 대한 설명입니다.', '이슈장소_kor': 'Wien', '키워드_kor': '장벽 <br/>교통관제용의 기기 <br/>기둥 <br/>광폭 <br/>원형인 채 형성된 것', '관련 이미지_kor': []}
# {'기준년도_org': '2024', '참조번호_org': 'ATBTI2024000487-DEC', '시행일자_org': '2024-09-30', '결정세번_org': '39269097**************', '물품설명_org': 'Andere Ware aus Kunststoff, in Form eines Gurtes,<br/>- bestehend aus einem, im Spritzgussverfahren hergestellten thermoplastischen Polyurethan (laut Antragsteller),<br/>- mit den Maßen von 1500 x 6 x 52mm (LxBxH),<br/>- über die gesamte Länge perforiert,<br/>- mit einer Schnalle aus Aluminium und Kunststoffstoppern (für die Einstellung des Gurt-Durchmessers) ausgestattet.<br/>Dient dem Tragen diverser Gegenstände wie Waffenhalterung, Handschellen u.ä. während eines Polizei-Einsatzes. Stellt im Hinblick auf die Bedeutung in Bezug auf die Verwendung kein Bekleidungszubehör dar. Der Charakter der Ware wird bezüglich des Umfanges durch den Kunststoff bestimmt.<br/>(Abbildung siehe Anlage)', '분류사유_org': 'Allgemeine Vorschriften für die Auslegung der Kombinierten Nomenklatur (AV) 1, 3b und 6;<br/>Anmerkung 1 zu Kapitel 39;<br/>Erläuterungen zum HS zu Position 3926, 1. Absatz.', '이슈장소_org': 'Wien', '키워드_org': 'ALUMINIUM<br/>OF ALUMINIUM<br/>OF PLASTICS<br/>OF POLYURETHANE<br/>CLOTHING ACCESSORIES<br/>STRAPS<br/>PROPS', '관련 이미지_org': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241120-000059664886AN8Z'], '기준년도_eng': '2024', '참조번호_eng': 'ATBTI2024000487-DEC', '시행일자_eng': '2024-09-30', '결정세번_eng': '39269097**************', '물품설명_eng': 'Other plastic goods in the form of a belt, - consisting of a thermoplastic polyurethane produced by injection molding (according to the applicant), - with dimensions of 1500 x 6 x 52mm (LxWxH), - perforated along the entire length, - equipped with an aluminum buckle and plastic stoppers (for adjusting the belt diameter). Used for carrying various items such as weapon holders, handcuffs, etc. during a police operation. In view of its importance in relation to use, it does not constitute a clothing accessory. The nature of the goods is determined by the plastic in terms of its size. (See attachment for illustration)', '분류사유_eng': 'General rules for the interpretation of the Combined Nomenclature (GC) 1, 3b and 6; Note 1 to Chapter 39; HS Explanatory Notes to heading 3926, 1st paragraph.', '이슈장소_eng': 'Wien', '키워드_eng': 'ALUMINIUM<br/>OF ALUMINIUM<br/>OF PLASTICS<br/>OF POLYURETHANE<br/>CLOTHING ACCESSORIES<br/>STRAPS<br/>PROPS', '관련 이미지_eng': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241120-000059664886AN8Z'], '기준년도_kor': '2024', '참조번호_kor': 'ATBTI2024000487-DEC', '시행일자_kor': '2024-09-30', '결정세번_kor': '39269097**************', '물품설명_kor': '벨트 형태의 플라스틱으로 만든 기타 제품 - 사출 성형으로 생산된 열가소성 폴리우레탄으로 구성됨(신청자에 따라) - 치수가 1500 x 6 x 52mm(LxWxH)이고 - 전체 길이에 천공되어 있음 - 알루미늄 및 플라스틱 스토퍼로 제작된 버클 포함(벨트 직경 조정용). 무기홀더, 수갑 등 다양한 물품을 운반하는데 사용됩니다. 경찰 작전 중. 사용상의 중요성을 고려할 때, 제품의 특성은 크기에 따른 플라스틱을 의미하지 않습니다. (그림은 첨부 파일 참조)', '분류사유_kor': '결합명명법(AV) 1, 3b 및 6의 해석을 위한 일반 규칙 제39류 주1; 위치 3926, 첫 번째 단락에 대한 HS에 대한 설명입니다.', '이슈장소_kor': 'Wien', '키워드_kor': '알루미늄박 <br/>알루미늄제의 것 <br/>플라스틱제의 것 <br/>폴리우레탄의 것 <br/>의류 부속품 <br/>스트랩 <br/>프로프', '관련 이미지_kor': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241120-000059664886AN8Z']}
# {'기준년도_org': '2023', '참조번호_org': 'IEBTIIENEN004-2023-BTI559', '시행일자_org': '2023-10-17', '결정세번_org': '85444290**************', '물품설명_org': 'Insulated electrical cable <br/>Equipped with a type USB C connector on one end and lightning connector on the other end.<br/>For a voltage of 5 VDC.<br/>With a length of 1.5m.<br/>Rugged, braided Kevlar cable.<br/>Intended for connecting and charging devices and for data transfer between the connected devices.<br/>Suitable for iPhone, iPad and iPod devices.', '분류사유_org': 'GIR 1 and 6<br/>HSEN To Heading 8544<br/>Text to Code 8544, 8544 42, 8544 42 90, 8544 42 90 90', '이슈장소_org': 'Nenagh', '키워드_org': 'CABLES <br/>WITH CONNECTORS <br/>INSULATED <br/>USB CONNECTORS <br/>FOR A VOLTAGE NOT &gt; 1000 V', '관련 이미지_org': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241202-000059847396AN8Z'], '기준년도_eng': '2023', '참조번호_eng': 'IEBTIIENEN004-2023-BTI559', '시행일자_eng': '2023-10-17', '결정세번_eng': '85444290**************', '물품설명_eng': 'Insulated electrical cable <br/>Equipped with a type USB C connector on one end and lightning connector on the other end.<br/>For a voltage of 5 VDC.<br/>With a length of 1.5m.<br/>Rugged, braided Kevlar cable.<br/>Intended for connecting and charging devices and for data transfer between the connected devices.<br/>Suitable for iPhone, iPad and iPod devices.', '분류사유_eng': 'GIR 1 and 6<br/>HSEN To Heading 8544<br/>Text to Code 8544, 8544 42, 8544 42 90, 8544 42 90 90', '이슈장소_eng': 'Nenagh', '키워드_eng': 'CABLES <br/>WITH CONNECTORS <br/>INSULATED <br/>USB CONNECTORS <br/>FOR A VOLTAGE NOT &gt; 1000 V', '관련 이미지_eng': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241202-000059847396AN8Z'], '기준년도_kor': '2023', '참조번호_kor': 'IEBTIIENEN004-2023-BTI559', '시행일자_kor': '2023-10-17', '결정세번_kor': '85444290**************', '물품설명_kor': '절연 전기 케이블 한쪽 끝에 USB C형 커넥터, 다른 쪽 끝에 번개 커넥터가 장착되어 있습니다. 5 VDC 전압용입니다. 길이 1.5m입니다. 견고한 브레이디드 케블라 케이블입니다. 장치를 연결하고 충전하고 연결된 장치 간의 데이터 전송을 위해 고안되었습니다. iPhone, iPad 및 iPod 장치에 적합합니다.', '분류사유_kor': 'GIR 1 및 6 HSEN 제목 8544 텍스트 코드 8544, 8544 42, 8544 42 90, 8544 42 90 90', '이슈장소_kor': 'Nenagh', '키워드_kor': '케이블  <br/>커넥터로  <br/>절연된 것  <br/>USB 커넥터  <br/>&gt; 1000 V가 아니라 전압을 위한 것', '관련 이미지_kor': ['/clip/framework/filedownload/kcs4gImageDownload.do?attchFileId=ULS-20241202-000059847396AN8Z']}

# %%
directory = 'org/' 
error_file_names = [f'error_stt_{i}.txt' for i in range(12)]
all_error_data = []
# Đọc và xử lý từng file
for file_name in error_file_names:
    file_path = os.path.join(directory, file_name)
    with open(file_path, 'r', encoding='utf-8') as file:
        data = [json.loads(line) for line in file]
        all_error_data.extend(data) 
error_df = pd.DataFrame(all_error_data)
error_df.to_csv('all_error_stt_1802.csv', index=False, encoding='utf-8')

output_file_names = [f'output_data_{i}.txt' for i in range(12)]
all_output_data = []
# Đọc và xử lý từng file
for file_name in output_file_names:
    file_path = os.path.join(directory, file_name)
    with open(file_path, 'r', encoding='utf-8') as file:
        data = [json.loads(line) for line in file]
        all_output_data.extend(data)  
        
output_df = pd.DataFrame(all_output_data)
output_df.to_csv('all_output_data_1802.csv', index=False, encoding='utf-8')
