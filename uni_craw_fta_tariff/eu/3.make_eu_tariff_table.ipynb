# %%
import pandas as pd
import ast
import json

# %%
with open('tariff_info.txt', 'r', encoding='utf-8') as file:
    data = [json.loads(line) for line in file]

# %%
df = pd.DataFrame(data)
df['id'] = df.index + 1

# %%
df
# Out:
#       id hsCode description      origin                    type measureType  \
# 0      1   None        None  ERGA OMNES      Third country duty         103
# 1      2   None        None  ERGA OMNES      Third country duty         103
# 2      3   None        None  ERGA OMNES  Import control - CITES         710
# 3      4   None        None  ERGA OMNES      Third country duty         103
# 4      5   None        None    Viet Nam       Tariff preference         142
# ..   ...    ...         ...         ...                     ...         ...
# 396  397   None        None    Viet Nam       Tariff preference         142
# 397  398   None        None  ERGA OMNES      Third country duty         103
# 398  399   None        None    Viet Nam       Tariff preference         142
# 399  400   None        None  ERGA OMNES      Third country duty         103
# 400  401   None        None    Viet Nam       Tariff preference         142
#
#     geographicalArea geographicalSigl regulationRoleType regulationId  ...  \
# 0               1011             TOUT                  1     R8726580  ...
# 1               1011             TOUT                  1     R8726580  ...
# 2               1011             TOUT                  4     R2309660  ...
# 3               1011             TOUT                  4     R9922040  ...
# 4                 VN               VN                  1     D2007530  ...
# ..               ...              ...                ...          ...  ...
# 396               VN               VN                  1     D2007530  ...
# 397             1011             TOUT                  4     R9922040  ...
# 398               VN               VN                  1     D2007530  ...
# 399             1011             TOUT                  4     R9922040  ...
# 400               VN               VN                  1     D2007530  ...
#
#       startDate     endDate additionalCodeId additionalCodeText exclusions  \
# 0    01/01/2005        None             None               None       None
# 1    15/09/1994        None             None               None       None
# 2    20/05/2023  01/01/3000             None               None       None
# 3    01/07/2000  01/01/3000             None               None       None
# 4    01/08/2020        None             None               None       None
# ..          ...         ...              ...                ...        ...
# 396  01/08/2020        None             None               None       None
# 397  01/07/2000  01/01/3000             None               None       None
# 398  01/08/2020        None             None               None       None
# 399  01/07/2000  01/01/3000             None               None       None
# 400  01/08/2020        None             None               None       None
#
#     tariffFormula                                          footnotes  \
# 0              0%                                                 []
# 1              0%                                                 []
# 2            None  [{'code': 370, 'type': 'CD', 'text': 'If the p...
# 3           1.60%                                                 []
# 4              0%                                                 []
# ..            ...                                                ...
# 396            0%                                                 []
# 397         9.60%                                                 []
# 398            0%                                                 []
# 399         3.20%                                                 []
# 400            0%                                                 []
#
#                                             conditions hs_info_code country
# 0                                                   []         0501      AT
# 1                                                   []         0510      AT
# 2    [{'measureID': 0, 'type': 'Y', 'sequenceNumber...         0510      AT
# 3                                                   []         0814      AT
# 4                                                   []         0814      AT
# ..                                                 ...          ...     ...
# 396                                                 []       081310      AT
# 397                                                 []       081320      AT
# 398                                                 []       081320      AT
# 399                                                 []       081330      AT
# 400                                                 []       081330      AT
#
# [401 rows x 21 columns]

# %%
measure_df = df.drop(columns=['hsCode','footnotes','conditions'])

# %%
footnotes_list = []
for index, row in df.iterrows():
    footnotes_raw = row["footnotes"]

    if pd.isna(footnotes_raw) or footnotes_raw in ["", "[]", None]:
        continue
    
    try:
        # Dùng ast.literal_eval() để chuyển đổi từ chuỗi sang danh sách Python
        footnotes = ast.literal_eval(footnotes_raw)

        # Nếu không phải danh sách, bỏ qua
        if not isinstance(footnotes, list):
            continue
        
        for footnote in footnotes:
            footnote["measure_id"] = row["id"]
            footnotes_list.append(footnote)

    except (ValueError, SyntaxError) as e:
        print(f"⚠️ Lỗi khi parse JSON tại dòng {index}: {footnotes_raw} - {e}")

# Chuyển thành DataFrame
footnotes_df = pd.DataFrame(footnotes_list)

# %%
footnotes_df
# Out:
#      code type                                               text  measure_id
# 0     370   CD  If the product is mentioned in the list annexe...           3
# 1     775   CD  In case the goods are exported directly or ind...           9
# 2     370   CD  If the product is mentioned in the list annexe...          11
# 3     775   CD  In case the goods are exported directly or ind...          21
# 4     775   CD  In case the goods are exported directly or ind...          22
# ..    ...  ...                                                ...         ...
# 138   750   CD  Eligibility to benefit from this quota is subj...         346
# 139    83   CD  Entry into free circulation is subject to the ...         348
# 140   775   CD  In case the goods are exported directly or ind...         371
# 141     2   PB  The duty rate can be linked to the entry price...         382
# 142     2   PB  The duty rate can be linked to the entry price...         384
#
# [143 rows x 4 columns]

# %%
conditions_list = []
for index, row in df.iterrows():
    conditions_raw = row["conditions"]

    if pd.isna(conditions_raw) or conditions_raw in ["", "[]", None]:
        continue
    
    try:
        # Dùng ast.literal_eval() để chuyển đổi từ chuỗi sang danh sách Python
        conditions = ast.literal_eval(conditions_raw)

        # Nếu không phải danh sách, bỏ qua
        if not isinstance(conditions, list):
            continue
        
        for condition in conditions:
            condition["measure_id"] = row["id"]
            conditions_list.append(condition)

    except (ValueError, SyntaxError) as e:
        print(f"⚠️ Lỗi khi parse JSON tại dòng {index}: {conditions_raw} - {e}")

# Chuyển thành DataFrame
conditions_df = pd.DataFrame(conditions_list)
conditions_df = conditions_df.drop(columns=['measureID'])

# %%
conditions_df
# Out:
#     type sequenceNumber                                      description  \
# 0      Y              1                                 Other conditions
# 1      Y              2                                 Other conditions
# 2      Y              3                                 Other conditions
# 3      B              1   Presentation of a certificate/licence/document
# 4      B              2   Presentation of a certificate/licence/document
# ..   ...            ...                                              ...
# 236    Q              2  Presentation of an endorsed certificate/licence
# 237    C              1   Presentation of a certificate/licence/document
# 238    C              2   Presentation of a certificate/licence/document
# 239    B              1   Presentation of a certificate/licence/document
# 240    B              2   Presentation of a certificate/licence/document
#
#                                    actionDescription certificateType  \
# 0                Import/export allowed after control               C
# 1                Import/export allowed after control               Y
# 2            Import/export not allowed after control            None
# 3    Apply the amount of the action (see components)               Y
# 4    Apply the amount of the action (see components)            None
# ..                                               ...             ...
# 236                           Measure not applicable            None
# 237              Entry into free circulation allowed               U
# 238   The entry into free circulation is not allowed            None
# 239  Apply the amount of the action (see components)               Y
# 240  Apply the amount of the action (see components)            None
#
#     certificateNumber                             certificateDescription  \
# 0                 400   Presentation of the required "CITES" certificate
# 1                 900  Declared goods do not belong to the Washington...
# 2                None                                               None
# 3                 155  Products exported directly or indirectly from ...
# 4                None                                               None
# ..                ...                                                ...
# 236              None                                               None
# 237               004  Certificate of origin for imports of products ...
# 238              None                                               None
# 239               155  Products exported directly or indirectly from ...
# 240              None                                               None
#
#     conditionExpression tariffFormula  measure_id
# 0                  None          None           3
# 1                  None          None           3
# 2                  None          None           3
# 3                  None        50.00%           9
# 4                  None            0%           9
# ..                  ...           ...         ...
# 236                None          None         346
# 237                None          None         348
# 238                None          None         348
# 239                None        50.00%         371
# 240                None            0%         371
#
# [241 rows x 10 columns]

# %%
measure_df.to_csv('output/tariff_measure.csv')
footnotes_df.to_csv('output/tariff_measure_footnotes_df.csv')
conditions_df.to_csv('output/tariff_measure_conditions_df.csv')
